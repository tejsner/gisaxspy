# %%
# Notebook test on GitHub
from D1Gisaxs import *
# %matplotlib inline

# %%
data = gisaxs_thickness('data/SVA_pspb05_CHX_1.csv', 'data/pspb05_all', 3, 31, d1_2015=True)
plot_gisaxs_thickness(data, plot_phi=True)
# Out:
# d_dry = 227.9 nm
# d_max = 466.0 nm
# phi_min = 0.489055793991

# %%
show_2d_colorplot('data/PSPB_CHX_2015_03_colorplot_qz.dat', data, 'qz', colorlim=(10.0, 5e3))
show_2d_colorplot('data/PSPB_CHX_2015_03_colorplot_qy.dat', data, 'qy', colorlim=(10.0, 3e3))

# %%
# experiment details
SD = 1845.0*milimeter
pixel_size = 46.9*micrometer
db_x = 534
db_y = 53
alpha_i = 0.14*degree
wavelength = 1.155*angstrom
experiment = [SD, pixel_size, db_x, db_y, alpha_i, wavelength]
pixel_extent = [100, 100, 900, 600]

# %%
title = get_gisaxs_image_title(180, data)
show_gisaxs_image('data/', 'pspb05_180.tif', experiment, p_extent=pixel_extent, imgtitle=title, colorlim=(10.0,7e3))
